# %% [markdown]
# ### IBM HR Analytics Employee Attrition & Performance
#
# #### Dicionário de dados
#
# |Índice | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Valor Numérico                                                                                                                                                |
# |  1 | Attrition                  | Funcionário deixando a empresa - Texto - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Texto - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Valor Numérico - Nível Salarial                                                                                                                                 |
# |  4 | Department                 | Texto - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Valor Numérico - distância do trabalho até a casa em milhas
# |  6 | Education                  | Valor Numérico - 1=Abaixo da graduação, 2=Graduação, 3=Bacharelado, 4=Mestrado, 5=Doutorado   |
# |  7 | EducationField            | Texto - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Valor Numérico - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Valor Numérico - ID do Funcionário                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Valor Numérico - 1=Baixo, 2=Médio, 3=Alto, 4=Muito Alto |
# | 11 | Gender                     | Texto - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Valor Numérico - Salário por Hora                                                                                                                                |
# | 13 | JobInvolvement            | Valor Numérico - 1=Baixo, 2=Médio, 3=Alto, 4=Muito Alto                                                                                                         |
# | 14 | JobLevel                  | Valor Numérico - 1, 2, 3, 4, 5. Significa diferentes níveis de trabalho                                                                                                     |
# | 15 | JobRole                   | Texto - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Valor Numérico - 1=Baixo, 2=Médio, 3=Alto, 4=Muito Alto                                                                                                         |
# | 17 | MaritalStatus             | Texto - Solteiro, Casado, Divorciado                                                                                                                                      |
# | 18 | MonthlyIncome             | Valor Numérico - Salário Mensal                                                                                                                               |
# | 19 | MonthlyRate                | Valor Numérico - Taxa Mensal                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Valor Numérico - Número de empresas em que trabalhou                                                                                                                |
# | 21 | Over18                    | Texto - Y                                                                                                                                                    |
# | 22 | Overtime                   | Texto - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Valor Numérico - Percentual de aumento salarial                                                                                                                |
# | 24 | PerformanceRating         | Valor Numérico - 1=Baixo, 2=Bom, 3=Excelente, 4=Excepcional                                                                                                    |
# | 25 | RelationshipSatisfaction  | Valor Numérico - 1=Baixo, 2=Médio, 3=Alto, 4=Muito Alto                                                                                                         |
# | 26 | StandardHours             | Valor Numérico - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Valor Numérico - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Valor Numérico - Total de anos trabalhados                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Valor Numérico - Quantas vezes o funcionário foi treinado no último ano                                                                                       |
# | 30 | WorkLifeBalance          | Valor Numérico - 1=Ruim, 2=Bom, 3=Melhor, 4=Ótimo                                                                                                              |
# | 31 | YearsAtCompany           | Valor Numérico - Número de anos na empresa                                                                                                                |
# | 32 | YearsInCurrentRole      | Valor Numérico - Número de anos no cargo atual                                                                                                                |
# | 33 | YearsSinceLastPromotion | Valor Numérico - Anos desde a última promoção                                                                                                                    |
# | 34 | YearsWithCurrManager | Valor Numérico - Anos com o gerente atual                                                                                                                    |

# %% [markdown]
# #### Importação e visualização do dataset

# %%
# Importando a biblioteca pandas
import pandas as pd

# Importação e visualização do dataset
DADOS = 'WA_Fn-UseC_-HR-Employee-Attrition.csv'
df = pd.read_csv(DADOS)

# %%
with pd.option_context("display.max_columns", 35):
    display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ### Análise exploratória dos dados

# %%
print(f"Total de valores nulos: {df.isnull().sum().sum()}")
# Out:
# Total de valores nulos: 0

# %%
print(f"Total de linhas duplicadas: {df.duplicated().sum()}")
# Out:
# Total de linhas duplicadas: 0

# %% [markdown]
# #### Exploração dos dados numéricos

# %%
with pd.option_context("float_format", "{:.2f}".format, "display.max_columns", 35):
    display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
# Exclusão de colunas que não são relevantes para a análise
df.drop(columns=['EmployeeCount', 'EmployeeNumber', 'StandardHours'], inplace=True)

# Justificativa para exclusão das colunas:
# - EmployeeCount: Contém apenas o valor 1 para todos os funcionários, não agregando informação
# - EmployeeNumber: Número de identificação único que não contribui para a análise
# - StandardHours: Todos os funcionários têm o mesmo valor (80), não tendo variabilidade para análise

# %%
# Função para contar outliers
def contar_outliers(df):
    """
    Conta o número de outliers em cada coluna numérica do DataFrame usando o método Intervalo Interquartil (IQR).
    
    Parâmetros:
    -----------
    df : pandas.DataFrame
        DataFrame contendo os dados a serem analisados
        
    Retorna:
    --------
    dict
        Dicionário com o nome das colunas numéricas como chaves e a quantidade 
        de outliers como valores
    """
    outliers_info = {}
    
    for coluna in df.select_dtypes(include=['number']).columns:
        Q1 = df[coluna].quantile(0.25)
        Q3 = df[coluna].quantile(0.75)
        IQR = Q3 - Q1 # Intervalo interquartil
        
        limite_inferior = Q1 - 1.5 * IQR
        limite_superior = Q3 + 1.5 * IQR
        
        outliers = df[(df[coluna] < limite_inferior) | (df[coluna] > limite_superior)]
        quantidade_outliers = outliers.shape[0]
        
        outliers_info[coluna] = quantidade_outliers
    
    # Ordena o dicionário pela quantidade de outliers (do maior para o menor)
    outliers_ordenados = dict(sorted(outliers_info.items(), key=lambda item: item[1], reverse=True))
    
    return outliers_ordenados

# %%
contar_outliers(df)
# Out:
# {'TrainingTimesLastYear': 238,
#  'PerformanceRating': 226,
#  'MonthlyIncome': 114,
#  'YearsSinceLastPromotion': 107,
#  'YearsAtCompany': 104,
#  'StockOptionLevel': 85,
#  'TotalWorkingYears': 63,
#  'NumCompaniesWorked': 52,
#  'YearsInCurrentRole': 21,
#  'YearsWithCurrManager': 14,
#  'Age': 0,
#  'DailyRate': 0,
#  'DistanceFromHome': 0,
#  'Education': 0,
#  'EnvironmentSatisfaction': 0,
#  'HourlyRate': 0,
#  'JobInvolvement': 0,
#  'JobLevel': 0,
#  'JobSatisfaction': 0,
#  'MonthlyRate': 0,
#  'PercentSalaryHike': 0,
#  'RelationshipSatisfaction': 0,
#  'WorkLifeBalance': 0}

# %% [markdown]
# #### Exploração dos dados categóricos

# %%
df.describe(exclude='number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.drop(columns=['Over18'], inplace=True)

# Justificativa para exclusão da coluna:
# - Over18: Todos os funcionários têm o valor 'Y', indicando que são maiores de 18 anos.
# Esta coluna não agrega nenhuma informação relevante para a análise.
